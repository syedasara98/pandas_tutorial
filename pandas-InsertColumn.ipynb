# %%
import pandas as pd
nba1=pd.read_csv("nbasalaries.csv")

# %%
nba1.insert(3,column="Sport",value="FootBall")
nba1
# Out:
#      Unnamed: 0   RK                  Player     Sport                 TEAM  \
# 0             0    1             Kobe Bryant  FootBall   Los Angeles Lakers
# 1             1    2            LeBron James  FootBall  Cleveland Cavaliers
# 2             2    3         Carmelo Anthony  FootBall      New York Knicks
# 3             3    4           Dwight Howard  FootBall      Houston Rockets
# 4             4    5              Chris Bosh  FootBall           Miami Heat
# ..          ...  ...                     ...       ...                  ...
# 415         415  416         Orlando Johnson  FootBall         Phoenix Suns
# 416         416  417            Phil Pressey  FootBall         Phoenix Suns
# 417         417  418         Elliot Williams  FootBall    Memphis Grizzlies
# 418         418  419          Cory Jefferson  FootBall         Phoenix Suns
# 419         419  420  Thanasis Antetokounmpo  FootBall      New York Knicks
#
#            SALARY
# 0    $25,000,000
# 1    $22,970,500
# ...
