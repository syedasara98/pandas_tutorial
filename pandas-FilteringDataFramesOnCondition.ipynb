# %%
import pandas as pd
df=pd.read_csv("employees.csv")
df.head()
# Out:
#             Name Department     Manager  Salary  Star_date Last Login Time  \
# 0     Robin Hood        NaN         NaN     200  8/12/1998        12:45 PM
# 1  Arsene Wenger        Bar  Friar Tuck      50  7/11/1999        13:10 AM
# 2     Friar Tuck        Foo  Robin Hood     100   6/4/1996        15:09 PM
# 3    Little John        Foo  Robin Hood     100   5/3/1996        16:19 AM
# 4  Sam Allardyce        NaN         NaN     250   4/6/1997        13:10 PM
#
#    Senior Management  Gender
# 0               True    male
# 1              False  female
# 2              False    male
# 3               True    male
# 4               True  female

# %%
filter=df["Gender"]=='male'
df[filter]
# Out:
#             Name Department      Manager  Salary  Star_date Last Login Time  \
# 0     Robin Hood        NaN          NaN     200  8/12/1998        12:45 PM
# 2     Friar Tuck        Foo   Robin Hood     100   6/4/1996        15:09 PM
# 3    Little John        Foo   Robin Hood     100   5/3/1996        16:19 AM
# 5  Dimi Berbatov        Foo  Little John      50   5/6/1998        13:10 AM
#
#    Senior Management Gender
# 0               True   male
# 2              False   male
# 3               True   male
# 5               True   male

# %%
filter=df["Senior Management"]==True
df[filter]
# Out:
#             Name Department      Manager  Salary  Star_date Last Login Time  \
# 0     Robin Hood        NaN          NaN     200  8/12/1998        12:45 PM
# 3    Little John        Foo   Robin Hood     100   5/3/1996        16:19 AM
# 4  Sam Allardyce        NaN          NaN     250   4/6/1997        13:10 PM
# 5  Dimi Berbatov        Foo  Little John      50   5/6/1998        13:10 AM
#
#    Senior Management  Gender
# 0               True    male
# 3               True    male
# 4               True  female
# 5               True    male

# %%
filter=df["Salary"] >= 100
df[filter]
# Out:
#             Name Department     Manager  Salary  Star_date Last Login Time  \
# 0     Robin Hood        NaN         NaN     200  8/12/1998        12:45 PM
# 2     Friar Tuck        Foo  Robin Hood     100   6/4/1996        15:09 PM
# 3    Little John        Foo  Robin Hood     100   5/3/1996        16:19 AM
# 4  Sam Allardyce        NaN         NaN     250   4/6/1997        13:10 PM
#
#    Senior Management  Gender
# 0               True    male
# 2              False    male
# 3               True    male
# 4               True  female
